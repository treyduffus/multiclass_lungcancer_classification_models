# %%
# Group 33, Florida Atlantic University
# Fold change model for feature extraction
# 11/19/24

import numpy as np
import pandas as pd

# Extracting Data 
labeled_miRNA_data = pd.read_csv('../processed_data/miRNA_stage_subtype.csv')

# %%
labeled_miRNA_data.head(5)
# Out:
#    hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# 0   7314.747386   7391.483138   7334.393081  10994.201497   471.496698
# 1   9518.042994   9460.443528   9574.874468  17578.281899   785.810318
# 2   4479.976340   4387.407628   4447.955716  12394.310110   404.624244
# 3  21277.962603  21166.590502  21255.800397  15161.474118  6684.570363
# 4   8002.355461   8013.396682   8033.638922  19358.942067  1276.411235
#
#    hsa-let-7d   hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2   hsa-let-7g  ...  \
# 0  318.193106  1156.241547   3272.099771   3363.611772   442.783758  ...
# 1  358.652676   771.986446   3871.452122   3917.224498   487.829079  ...
# 2  855.241747   246.267705   1353.016896   1415.311564   416.850300  ...
# 3  503.278464  2185.922959  15012.229891  14987.262342  1107.549261  ...
# 4  765.754731   593.005616   2630.801098   2649.433160   367.580673  ...
#
#    hsa-mir-943  hsa-mir-944  hsa-mir-95  hsa-mir-9500  hsa-mir-96  hsa-mir-98  \
# 0          0.0     0.000000    1.847031             0   40.298863   35.429417
# 1          0.0   128.562009    4.607957             0    8.601520   38.860440
# 2          0.0   161.267504    1.746579             0   33.767203   31.438430
# 3          0.0     1.683206   10.660302             0    5.049617   95.101114
# 4          0.0    97.990843    3.450382             0   22.772520   46.235116
#
#    hsa-mir-99a   hsa-mir-99b  stage  subtype
# 0   148.602058  12118.707689      1        2
# 1   111.512567   7471.802757      1        2
# 2   168.253822  16026.613214      1        2
# 3  1416.978551  12750.562682      1        2
# 4   455.450396  14401.203493      1        2
#
# [5 rows x 1883 columns]

# %%
# Averaging the rpm for each miRNA based on the stage (0 == healthy/negative)
rpm_avg_across_stages = labeled_miRNA_data.iloc[: ,:  -1].groupby('stage').mean()

positive_cases = rpm_avg_across_stages[1:]

# Averaging the averages of unhealthy/posistive cases
rpm_avg_posistive_cases = positive_cases.mean().to_frame().transpose()

rpm_avg_negative_posistive = pd.concat([rpm_avg_across_stages.iloc[:1], rpm_avg_posistive_cases.iloc[:1]], ignore_index = True).transpose()

rpm_avg_negative_posistive.head(5)
# Out:
#                          0             1
# hsa-let-7a-1   9364.865318   9854.354250
# hsa-let-7a-2   9319.533377   9839.225444
# hsa-let-7a-3   9399.771735   9885.311293
# hsa-let-7b    15241.225121  17199.333693
# hsa-let-7c     1979.238756   1550.109942

# %%
def log_fold_change(miRNA, negative, posistive):
    # miRNAs with low regulation averaged 0 for the negative dataset
    if negative == 0: 
        print(f'Warning divide by zero on : \n{miRNA}')
        print(f'Negative: {negative}')
        print(f'Posistive: {posistive}\n')
        return 0
    # Adding a small value to avoid divide by zero errors
    negative += 0.0001
    posistive += 0.0001
    return np.log2(posistive / negative)

# %%
rpm_log_fold_change = {}

for idx, row in rpm_avg_negative_posistive.iterrows():
    rpm_log_fold_change[row.name] = log_fold_change(row.name, row[0], row[1])
# Out:
# Warning divide by zero on :
# hsa-mir-103b-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-103b-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1182
# Negative: 0.0
# Posistive: 0.008314896875430224
#
# Warning divide by zero on :
# hsa-mir-1183
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1184-1
# Negative: 0.0
# Posistive: 0.00013165503246753249
#
# Warning divide by zero on :
# hsa-mir-1184-2
# Negative: 0.0
# Posistive: 0.00042385740282685513
#
# Warning divide by zero on :
# hsa-mir-1184-3
# Negative: 0.0
# Posistive: 0.00011577759740259739
#
# Warning divide by zero on :
# hsa-mir-1193
# Negative: 0.0
# Posistive: 0.011515541323711624
#
# Warning divide by zero on :
# hsa-mir-1199
# Negative: 0.0
# Posistive: 0.003159557647767427
#
# Warning divide by zero on :
# hsa-mir-1200
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1202
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1203
# Negative: 0.0
# Posistive: 0.00048761980290027996
#
# Warning divide by zero on :
# hsa-mir-1204
# Negative: 0.0
# Posistive: 0.0007793434990362993
#
# Warning divide by zero on :
# hsa-mir-1205
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1206
# Negative: 0.0
# Posistive: 0.00012312941696113072
#
# Warning divide by zero on :
# hsa-mir-1207
# Negative: 0.0
# Posistive: 0.0007800698071451517
#
# Warning divide by zero on :
# hsa-mir-1208
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1233-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1233-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1244-1
# Negative: 0.0
# Posistive: 0.0025970893507566753
#
# Warning divide by zero on :
# hsa-mir-1244-2
# Negative: 0.0
# Posistive: 0.001035367401909045
#
# Warning divide by zero on :
# hsa-mir-1244-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1244-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1253
# Negative: 0.0
# Posistive: 0.0037997997486384585
#
# Warning divide by zero on :
# hsa-mir-1255b-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1255b-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1260a
# Negative: 0.0
# Posistive: 0.002419435937543022
#
# Warning divide by zero on :
# hsa-mir-1261
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1263
# Negative: 0.0
# Posistive: 0.009849453897939517
#
# Warning divide by zero on :
# hsa-mir-1264
# Negative: 0.0
# Posistive: 0.052586004703088426
#
# Warning divide by zero on :
# hsa-mir-1268a
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1268b
# Negative: 0.0
# Posistive: 0.0005677727760313891
#
# Warning divide by zero on :
# hsa-mir-1272
# Negative: 0.0
# Posistive: 0.001615583423572324
#
# Warning divide by zero on :
# hsa-mir-1273a
# Negative: 0.0
# Posistive: 0.00017984805653710248
#
# Warning divide by zero on :
# hsa-mir-1273d
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1273e
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1273f
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1273g
# Negative: 0.0
# Posistive: 0.00022664178445229685
#
# Warning divide by zero on :
# hsa-mir-1279
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1281
# Negative: 0.0
# Posistive: 0.005241424560820464
#
# Warning divide by zero on :
# hsa-mir-1283-2
# Negative: 0.0
# Posistive: 0.6392646933671603
#
# Warning divide by zero on :
# hsa-mir-1285-1
# Negative: 0.0
# Posistive: 0.03678857445687848
#
# Warning divide by zero on :
# hsa-mir-1285-2
# Negative: 0.0
# Posistive: 0.0003404478483089349
#
# Warning divide by zero on :
# hsa-mir-1290
# Negative: 0.0
# Posistive: 0.011054823709673717
#
# Warning divide by zero on :
# hsa-mir-1297
# Negative: 0.0
# Posistive: 0.0005017961408379605
#
# Warning divide by zero on :
# hsa-mir-1299
# Negative: 0.0
# Posistive: 0.0004077814285714286
#
# Warning divide by zero on :
# hsa-mir-1302-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-10
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-11
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-3
# Negative: 0.0
# Posistive: 0.011863369485659957
#
# Warning divide by zero on :
# hsa-mir-1302-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-5
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-6
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-7
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-8
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1302-9
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1303
# Negative: 0.0
# Posistive: 0.04712504007479412
#
# Warning divide by zero on :
# hsa-mir-1321
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1322
# Negative: 0.0
# Posistive: 0.007248405170253776
#
# Warning divide by zero on :
# hsa-mir-1324
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1469
# Negative: 0.0
# Posistive: 0.00023254464285714285
#
# Warning divide by zero on :
# hsa-mir-1470
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1471
# Negative: 0.0
# Posistive: 6.356492932862191e-05
#
# Warning divide by zero on :
# hsa-mir-147a
# Negative: 0.0
# Posistive: 0.001791792513881878
#
# Warning divide by zero on :
# hsa-mir-1587
# Negative: 0.0
# Posistive: 0.0004362226865449038
#
# Warning divide by zero on :
# hsa-mir-1825
# Negative: 0.0
# Posistive: 0.011045005680793047
#
# Warning divide by zero on :
# hsa-mir-1827
# Negative: 0.0
# Posistive: 0.00015221554770318023
#
# Warning divide by zero on :
# hsa-mir-1972-1
# Negative: 0.0
# Posistive: 0.0002247042857142857
#
# Warning divide by zero on :
# hsa-mir-1972-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-1973
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-2052
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-2053
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-2054
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-208a
# Negative: 0.0
# Posistive: 0.00271695852542334
#
# Warning divide by zero on :
# hsa-mir-2117
# Negative: 0.0
# Posistive: 0.033697288169631294
#
# Warning divide by zero on :
# hsa-mir-2392
# Negative: 0.0
# Posistive: 4.308524734982333e-05
#
# Warning divide by zero on :
# hsa-mir-2861
# Negative: 0.0
# Posistive: 0.007561878906199807
#
# Warning divide by zero on :
# hsa-mir-2909
# Negative: 0.0
# Posistive: 9.631493506493507e-05
#
# Warning divide by zero on :
# hsa-mir-297
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-298
# Negative: 0.0
# Posistive: 0.0023031327433047973
#
# Warning divide by zero on :
# hsa-mir-300
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-302c
# Negative: 0.0
# Posistive: 0.0009375914310954064
#
# Warning divide by zero on :
# hsa-mir-302d
# Negative: 0.0
# Posistive: 0.007354668094300547
#
# Warning divide by zero on :
# hsa-mir-302e
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-302f
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3118-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3118-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3118-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3118-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3119-1
# Negative: 0.0
# Posistive: 0.0025370993816254414
#
# Warning divide by zero on :
# hsa-mir-3119-2
# Negative: 0.0
# Posistive: 0.0012521556290441007
#
# Warning divide by zero on :
# hsa-mir-3120
# Negative: 0.0
# Posistive: 0.015882799454228665
#
# Warning divide by zero on :
# hsa-mir-3121
# Negative: 0.0
# Posistive: 0.009297104061194989
#
# Warning divide by zero on :
# hsa-mir-3122
# Negative: 0.0
# Posistive: 0.0030280817485688824
#
# Warning divide by zero on :
# hsa-mir-3123
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3125
# Negative: 0.0
# Posistive: 0.053257945200619224
#
# Warning divide by zero on :
# hsa-mir-3132
# Negative: 0.0
# Posistive: 0.03509088218960625
#
# Warning divide by zero on :
# hsa-mir-3133
# Negative: 0.0
# Posistive: 0.03184150919092078
#
# Warning divide by zero on :
# hsa-mir-3134
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3135a
# Negative: 0.0
# Posistive: 0.011952517646312994
#
# Warning divide by zero on :
# hsa-mir-3135b
# Negative: 0.0
# Posistive: 9.34386042402827e-05
#
# Warning divide by zero on :
# hsa-mir-3141
# Negative: 0.0
# Posistive: 0.00122680460763618
#
# Warning divide by zero on :
# hsa-mir-3142
# Negative: 0.0
# Posistive: 0.006430245605880498
#
# Warning divide by zero on :
# hsa-mir-3147
# Negative: 0.0
# Posistive: 0.004281344563114988
#
# Warning divide by zero on :
# hsa-mir-3148
# Negative: 0.0
# Posistive: 0.008106836485731014
#
# Warning divide by zero on :
# hsa-mir-3153
# Negative: 0.0
# Posistive: 0.0035450325709859504
#
# Warning divide by zero on :
# hsa-mir-3155b
# Negative: 0.0
# Posistive: 0.001472188429678722
#
# Warning divide by zero on :
# hsa-mir-3156-1
# Negative: 0.0
# Posistive: 0.0007855385558257996
#
# Warning divide by zero on :
# hsa-mir-3156-2
# Negative: 0.0
# Posistive: 0.00010132597173144876
#
# Warning divide by zero on :
# hsa-mir-3156-3
# Negative: 0.0
# Posistive: 0.0003584864184755174
#
# Warning divide by zero on :
# hsa-mir-3160-1
# Negative: 0.0
# Posistive: 0.013133289064551659
#
# Warning divide by zero on :
# hsa-mir-3160-2
# Negative: 0.0
# Posistive: 0.01404569100912851
#
# Warning divide by zero on :
# hsa-mir-3167
# Negative: 0.0
# Posistive: 0.002130760580629618
#
# Warning divide by zero on :
# hsa-mir-3168
# Negative: 0.0
# Posistive: 0.004353659669703089
#
# Warning divide by zero on :
# hsa-mir-3169
# Negative: 0.0
# Posistive: 5.735909893992933e-05
#
# Warning divide by zero on :
# hsa-mir-3179-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3179-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3179-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3179-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3180-1
# Negative: 0.0
# Posistive: 0.0016607423630168416
#
# Warning divide by zero on :
# hsa-mir-3180-2
# Negative: 0.0
# Posistive: 0.0030214035372327433
#
# Warning divide by zero on :
# hsa-mir-3180-3
# Negative: 0.0
# Posistive: 0.0019235858215547702
#
# Warning divide by zero on :
# hsa-mir-3180-5
# Negative: 0.0
# Posistive: 0.0007392893109540636
#
# Warning divide by zero on :
# hsa-mir-3184
# Negative: 0.0
# Posistive: 0.002809652018149695
#
# Warning divide by zero on :
# hsa-mir-3185
# Negative: 0.0
# Posistive: 0.0008192239141159195
#
# Warning divide by zero on :
# hsa-mir-3197
# Negative: 0.0
# Posistive: 0.01756222408643847
#
# Warning divide by zero on :
# hsa-mir-3201
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-325
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3529
# Negative: 0.0
# Posistive: 0.0052475964783626275
#
# Warning divide by zero on :
# hsa-mir-3591
# Negative: 0.0
# Posistive: 0.0059747615344637696
#
# Warning divide by zero on :
# hsa-mir-3612
# Negative: 0.0
# Posistive: 0.0035328848230921023
#
# Warning divide by zero on :
# hsa-mir-3621
# Negative: 0.0
# Posistive: 0.0020708159821715387
#
# Warning divide by zero on :
# hsa-mir-3648-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3648-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3649
# Negative: 0.0
# Posistive: 0.004144849336308568
#
# Warning divide by zero on :
# hsa-mir-3657
# Negative: 0.0
# Posistive: 0.018264341862839942
#
# Warning divide by zero on :
# hsa-mir-3658
# Negative: 0.0
# Posistive: 0.020830293714555137
#
# Warning divide by zero on :
# hsa-mir-3659
# Negative: 0.0
# Posistive: 0.031364106261448574
#
# Warning divide by zero on :
# hsa-mir-3665
# Negative: 0.0
# Posistive: 0.0002670142857142857
#
# Warning divide by zero on :
# hsa-mir-3666
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3668
# Negative: 0.0
# Posistive: 0.004090459982561608
#
# Warning divide by zero on :
# hsa-mir-367
# Negative: 0.0
# Posistive: 0.00047674571428571433
#
# Warning divide by zero on :
# hsa-mir-3670-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3670-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3670-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3670-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3671
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3672
# Negative: 0.0
# Posistive: 0.00041467958859162037
#
# Warning divide by zero on :
# hsa-mir-3674
# Negative: 0.0
# Posistive: 8.209893992932862e-05
#
# Warning divide by zero on :
# hsa-mir-3675
# Negative: 0.0
# Posistive: 0.006454411839176725
#
# Warning divide by zero on :
# hsa-mir-3686
# Negative: 0.0
# Posistive: 0.0010092082342480842
#
# Warning divide by zero on :
# hsa-mir-3687-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3687-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3688-1
# Negative: 0.0
# Posistive: 0.051724701065033504
#
# Warning divide by zero on :
# hsa-mir-3688-2
# Negative: 0.0
# Posistive: 0.04877908039772635
#
# Warning divide by zero on :
# hsa-mir-3689b
# Negative: 0.0
# Posistive: 0.06863783135444716
#
# Warning divide by zero on :
# hsa-mir-3689c
# Negative: 0.0
# Posistive: 0.0006721826642880087
#
# Warning divide by zero on :
# hsa-mir-3689d-1
# Negative: 0.0
# Posistive: 0.00036183685064935064
#
# Warning divide by zero on :
# hsa-mir-3689d-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3690-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3713
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3714
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-378b
# Negative: 0.0
# Posistive: 0.009844362335512145
#
# Warning divide by zero on :
# hsa-mir-378e
# Negative: 0.0
# Posistive: 0.0014889234796475609
#
# Warning divide by zero on :
# hsa-mir-378g
# Negative: 0.0
# Posistive: 0.005342061955449942
#
# Warning divide by zero on :
# hsa-mir-378h
# Negative: 0.0
# Posistive: 0.00163387630971502
#
# Warning divide by zero on :
# hsa-mir-378j
# Negative: 0.0
# Posistive: 0.0003958103861686017
#
# Warning divide by zero on :
# hsa-mir-384
# Negative: 0.0
# Posistive: 0.0001036678445229682
#
# Warning divide by zero on :
# hsa-mir-3908
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3914-1
# Negative: 0.0
# Posistive: 0.005191765872493231
#
# Warning divide by zero on :
# hsa-mir-3914-2
# Negative: 0.0
# Posistive: 0.0031390466374879534
#
# Warning divide by zero on :
# hsa-mir-3915
# Negative: 0.0
# Posistive: 0.0012504360584645036
#
# Warning divide by zero on :
# hsa-mir-3924
# Negative: 0.0
# Posistive: 0.0006360854452526273
#
# Warning divide by zero on :
# hsa-mir-3927
# Negative: 0.0
# Posistive: 0.21692211966588382
#
# Warning divide by zero on :
# hsa-mir-3929
# Negative: 0.0
# Posistive: 0.04162787918844492
#
# Warning divide by zero on :
# hsa-mir-3935
# Negative: 0.0
# Posistive: 0.00165538702044422
#
# Warning divide by zero on :
# hsa-mir-3938
# Negative: 0.0
# Posistive: 0.0370053228511993
#
# Warning divide by zero on :
# hsa-mir-3960
# Negative: 0.0
# Posistive: 0.0035135565346007007
#
# Warning divide by zero on :
# hsa-mir-3972
# Negative: 0.0
# Posistive: 0.00017100142857142856
#
# Warning divide by zero on :
# hsa-mir-3973
# Negative: 0.0
# Posistive: 0.004478766129032258
#
# Warning divide by zero on :
# hsa-mir-3974
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3975
# Negative: 0.0
# Posistive: 0.00017222726699095956
#
# Warning divide by zero on :
# hsa-mir-3976
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3977
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-3978
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-422a
# Negative: 0.0
# Posistive: 0.00026922120370795284
#
# Warning divide by zero on :
# hsa-mir-4251
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4252
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4253
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4255
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4256
# Negative: 0.0
# Posistive: 0.001246349140700289
#
# Warning divide by zero on :
# hsa-mir-4257
# Negative: 0.0
# Posistive: 0.0001951499495204442
#
# Warning divide by zero on :
# hsa-mir-4258
# Negative: 0.0
# Posistive: 0.0017055246170437337
#
# Warning divide by zero on :
# hsa-mir-4259
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4260
# Negative: 0.0
# Posistive: 0.0003445808992244505
#
# Warning divide by zero on :
# hsa-mir-4261
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4262
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4263
# Negative: 0.0
# Posistive: 0.00042362831650681474
#
# Warning divide by zero on :
# hsa-mir-4264
# Negative: 0.0
# Posistive: 0.0002454757142857143
#
# Warning divide by zero on :
# hsa-mir-4265
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4266
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4267
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4268
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4269
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4270
# Negative: 0.0
# Posistive: 0.00017743639575971732
#
# Warning divide by zero on :
# hsa-mir-4271
# Negative: 0.0
# Posistive: 8.55410777385159e-05
#
# Warning divide by zero on :
# hsa-mir-4272
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4273
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4274
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4275
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4276
# Negative: 0.0
# Posistive: 0.0002776891233766234
#
# Warning divide by zero on :
# hsa-mir-4277
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4278
# Negative: 0.0
# Posistive: 0.00012565584415584415
#
# Warning divide by zero on :
# hsa-mir-4279
# Negative: 0.0
# Posistive: 0.0011323397646964342
#
# Warning divide by zero on :
# hsa-mir-4280
# Negative: 0.0
# Posistive: 0.0001366674028268551
#
# Warning divide by zero on :
# hsa-mir-4281
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4282
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4283-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4283-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4285
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4287
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4288
# Negative: 0.0
# Posistive: 0.00016055609540636042
#
# Warning divide by zero on :
# hsa-mir-4289
# Negative: 0.0
# Posistive: 0.001027969139323574
#
# Warning divide by zero on :
# hsa-mir-4290
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4291
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4292
# Negative: 0.0
# Posistive: 0.0006844905895782663
#
# Warning divide by zero on :
# hsa-mir-4293
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4294
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4295
# Negative: 0.0
# Posistive: 0.0002690075203065486
#
# Warning divide by zero on :
# hsa-mir-4296
# Negative: 0.0
# Posistive: 0.0006952146298930751
#
# Warning divide by zero on :
# hsa-mir-4297
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4298
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4299
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4300
# Negative: 0.0
# Posistive: 0.0013923413741023596
#
# Warning divide by zero on :
# hsa-mir-4301
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4302
# Negative: 0.0
# Posistive: 0.0003848257142857143
#
# Warning divide by zero on :
# hsa-mir-4303
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4304
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4305
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4307
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4308
# Negative: 0.0
# Posistive: 0.00045266872791519436
#
# Warning divide by zero on :
# hsa-mir-4309
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4311
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4312
# Negative: 0.0
# Posistive: 0.00021999734982332156
#
# Warning divide by zero on :
# hsa-mir-4313
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4314
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4315-1
# Negative: 0.0
# Posistive: 0.004516034626566013
#
# Warning divide by zero on :
# hsa-mir-4315-2
# Negative: 0.0
# Posistive: 0.004586391516795925
#
# Warning divide by zero on :
# hsa-mir-4316
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4317
# Negative: 0.0
# Posistive: 9.945373376623377e-05
#
# Warning divide by zero on :
# hsa-mir-4318
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4319
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4320
# Negative: 0.0
# Posistive: 0.00035478896103896106
#
# Warning divide by zero on :
# hsa-mir-4321
# Negative: 0.0
# Posistive: 0.00024994629376806935
#
# Warning divide by zero on :
# hsa-mir-4322
# Negative: 0.0
# Posistive: 0.0013978881791794778
#
# Warning divide by zero on :
# hsa-mir-4323
# Negative: 0.0
# Posistive: 0.00011334717314487634
#
# Warning divide by zero on :
# hsa-mir-4324
# Negative: 0.0
# Posistive: 0.00012582243816254416
#
# Warning divide by zero on :
# hsa-mir-4325
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4327
# Negative: 0.0
# Posistive: 0.00018789487632508837
#
# Warning divide by zero on :
# hsa-mir-4328
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4329
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4330
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4417
# Negative: 0.0
# Posistive: 0.00031932950530035335
#
# Warning divide by zero on :
# hsa-mir-4418
# Negative: 0.0
# Posistive: 0.00011574000000000001
#
# Warning divide by zero on :
# hsa-mir-4419a
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4420
# Negative: 0.0
# Posistive: 0.012607648952656543
#
# Warning divide by zero on :
# hsa-mir-4425
# Negative: 0.0
# Posistive: 0.021511464249334956
#
# Warning divide by zero on :
# hsa-mir-4427
# Negative: 0.0
# Posistive: 0.022648514756365826
#
# Warning divide by zero on :
# hsa-mir-4428
# Negative: 0.0
# Posistive: 0.004224685961047104
#
# Warning divide by zero on :
# hsa-mir-4429
# Negative: 0.0
# Posistive: 0.015158437143153212
#
# Warning divide by zero on :
# hsa-mir-4430
# Negative: 0.0
# Posistive: 0.01164215871274172
#
# Warning divide by zero on :
# hsa-mir-4432
# Negative: 0.0
# Posistive: 0.002723569185580463
#
# Warning divide by zero on :
# hsa-mir-4436a
# Negative: 0.0
# Posistive: 0.00047800750883392223
#
# Warning divide by zero on :
# hsa-mir-4436b-2
# Negative: 0.0
# Posistive: 0.04578122237853449
#
# Warning divide by zero on :
# hsa-mir-4437
# Negative: 0.0
# Posistive: 0.007417291405626176
#
# Warning divide by zero on :
# hsa-mir-4438
# Negative: 0.0
# Posistive: 0.00026715905935936854
#
# Warning divide by zero on :
# hsa-mir-4440
# Negative: 0.0
# Posistive: 0.00029651714285714283
#
# Warning divide by zero on :
# hsa-mir-4441
# Negative: 0.0
# Posistive: 0.00019038555194805196
#
# Warning divide by zero on :
# hsa-mir-4447
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4450
# Negative: 0.0
# Posistive: 0.01410611871444041
#
# Warning divide by zero on :
# hsa-mir-4451
# Negative: 0.0
# Posistive: 0.036366379163393886
#
# Warning divide by zero on :
# hsa-mir-4452
# Negative: 0.0
# Posistive: 0.012240047631361571
#
# Warning divide by zero on :
# hsa-mir-4455
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4456
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4458
# Negative: 0.0
# Posistive: 0.012729653805940155
#
# Warning divide by zero on :
# hsa-mir-4459
# Negative: 0.0
# Posistive: 0.00019588068181818183
#
# Warning divide by zero on :
# hsa-mir-4460
# Negative: 0.0
# Posistive: 0.0004186557142857143
#
# Warning divide by zero on :
# hsa-mir-4462
# Negative: 0.0
# Posistive: 0.0006101719480519481
#
# Warning divide by zero on :
# hsa-mir-4463
# Negative: 0.0
# Posistive: 0.00010819655477031803
#
# Warning divide by zero on :
# hsa-mir-4464
# Negative: 0.0
# Posistive: 0.0022127895176907897
#
# Warning divide by zero on :
# hsa-mir-4466
# Negative: 0.0
# Posistive: 0.038486336602840614
#
# Warning divide by zero on :
# hsa-mir-4467
# Negative: 0.0
# Posistive: 0.007807560361528361
#
# Warning divide by zero on :
# hsa-mir-4468
# Negative: 0.0
# Posistive: 0.003720945101447623
#
# Warning divide by zero on :
# hsa-mir-4471
# Negative: 0.0
# Posistive: 0.005484762827658207
#
# Warning divide by zero on :
# hsa-mir-4472-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4472-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4475
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4476
# Negative: 0.0
# Posistive: 0.004740729852117848
#
# Warning divide by zero on :
# hsa-mir-4477a
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4477b
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-448
# Negative: 0.0
# Posistive: 0.2152141847821385
#
# Warning divide by zero on :
# hsa-mir-4481
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4483
# Negative: 0.0
# Posistive: 0.00031595627208480564
#
# Warning divide by zero on :
# hsa-mir-4485
# Negative: 0.0
# Posistive: 0.0012420234184984625
#
# Warning divide by zero on :
# hsa-mir-4486
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4487
# Negative: 0.0
# Posistive: 0.10853105651634812
#
# Warning divide by zero on :
# hsa-mir-4493
# Negative: 0.0
# Posistive: 0.0012454731695424716
#
# Warning divide by zero on :
# hsa-mir-4495
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4496
# Negative: 0.0
# Posistive: 0.020455748412525294
#
# Warning divide by zero on :
# hsa-mir-4497
# Negative: 0.0
# Posistive: 0.002063760548391538
#
# Warning divide by zero on :
# hsa-mir-4498
# Negative: 0.0
# Posistive: 0.02259082710711436
#
# Warning divide by zero on :
# hsa-mir-4499
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4500
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4503
# Negative: 0.0
# Posistive: 0.0023721816910651184
#
# Warning divide by zero on :
# hsa-mir-4504
# Negative: 0.0
# Posistive: 0.009505563285667656
#
# Warning divide by zero on :
# hsa-mir-4505
# Negative: 0.0
# Posistive: 0.041153724113798834
#
# Warning divide by zero on :
# hsa-mir-4506
# Negative: 0.0
# Posistive: 0.002911352058933031
#
# Warning divide by zero on :
# hsa-mir-4508
# Negative: 0.0
# Posistive: 0.0004800414285714286
#
# Warning divide by zero on :
# hsa-mir-4509-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4509-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4509-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4512
# Negative: 0.0
# Posistive: 0.03915164038072835
#
# Warning divide by zero on :
# hsa-mir-4513
# Negative: 0.0
# Posistive: 0.006045268295741361
#
# Warning divide by zero on :
# hsa-mir-4514
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4518
# Negative: 0.0
# Posistive: 0.0071741715904057755
#
# Warning divide by zero on :
# hsa-mir-451b
# Negative: 0.0
# Posistive: 0.0035295998157496215
#
# Warning divide by zero on :
# hsa-mir-4520-1
# Negative: 0.0
# Posistive: 0.02086103697541231
#
# Warning divide by zero on :
# hsa-mir-4520-2
# Negative: 0.0
# Posistive: 0.013281045625998302
#
# Warning divide by zero on :
# hsa-mir-4524b
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4526
# Negative: 0.0
# Posistive: 0.018595438462068535
#
# Warning divide by zero on :
# hsa-mir-4531
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4534
# Negative: 0.0
# Posistive: 0.00042651937152953054
#
# Warning divide by zero on :
# hsa-mir-4535
# Negative: 0.0
# Posistive: 0.0001552573051948052
#
# Warning divide by zero on :
# hsa-mir-4538
# Negative: 0.0
# Posistive: 0.003414982430246432
#
# Warning divide by zero on :
# hsa-mir-4539
# Negative: 0.0
# Posistive: 0.009326040682965444
#
# Warning divide by zero on :
# hsa-mir-4540
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4633
# Negative: 0.0
# Posistive: 0.003296899764063589
#
# Warning divide by zero on :
# hsa-mir-4635
# Negative: 0.0
# Posistive: 0.00989323523332361
#
# Warning divide by zero on :
# hsa-mir-4642
# Negative: 0.0
# Posistive: 0.006476900677077397
#
# Warning divide by zero on :
# hsa-mir-4650-1
# Negative: 0.0
# Posistive: 0.0005739917693084302
#
# Warning divide by zero on :
# hsa-mir-4650-2
# Negative: 0.0
# Posistive: 0.000329555091551558
#
# Warning divide by zero on :
# hsa-mir-4651
# Negative: 0.0
# Posistive: 0.0496964878712838
#
# Warning divide by zero on :
# hsa-mir-4653
# Negative: 0.0
# Posistive: 0.03840350567343576
#
# Warning divide by zero on :
# hsa-mir-4655
# Negative: 0.0
# Posistive: 0.012744116426413835
#
# Warning divide by zero on :
# hsa-mir-4656
# Negative: 0.0
# Posistive: 0.0045379208047899335
#
# Warning divide by zero on :
# hsa-mir-4659b
# Negative: 0.0
# Posistive: 0.005271492388027167
#
# Warning divide by zero on :
# hsa-mir-4666b
# Negative: 0.0
# Posistive: 0.001124732922077922
#
# Warning divide by zero on :
# hsa-mir-4671
# Negative: 0.0
# Posistive: 0.024363562747901246
#
# Warning divide by zero on :
# hsa-mir-4675
# Negative: 0.0
# Posistive: 0.01826253886628247
#
# Warning divide by zero on :
# hsa-mir-4678
# Negative: 0.0
# Posistive: 0.07582617596440377
#
# Warning divide by zero on :
# hsa-mir-4679-1
# Negative: 0.0
# Posistive: 0.031714870044839465
#
# Warning divide by zero on :
# hsa-mir-4686
# Negative: 0.0
# Posistive: 0.0038491130770731035
#
# Warning divide by zero on :
# hsa-mir-4688
# Negative: 0.0
# Posistive: 0.004390466739250149
#
# Warning divide by zero on :
# hsa-mir-4692
# Negative: 0.0
# Posistive: 0.0008047971114221466
#
# Warning divide by zero on :
# hsa-mir-4693
# Negative: 0.0
# Posistive: 0.0012384639314395852
#
# Warning divide by zero on :
# hsa-mir-4694
# Negative: 0.0
# Posistive: 0.004179336376370978
#
# Warning divide by zero on :
# hsa-mir-4696
# Negative: 0.0
# Posistive: 0.010510002990029178
#
# Warning divide by zero on :
# hsa-mir-4698
# Negative: 0.0
# Posistive: 0.003320458914230646
#
# Warning divide by zero on :
# hsa-mir-4701
# Negative: 0.0
# Posistive: 0.035526650140547074
#
# Warning divide by zero on :
# hsa-mir-4704
# Negative: 0.0
# Posistive: 0.018187063771481566
#
# Warning divide by zero on :
# hsa-mir-4711
# Negative: 0.0
# Posistive: 0.0035266767385839963
#
# Warning divide by zero on :
# hsa-mir-4712
# Negative: 0.0
# Posistive: 0.010093015326466536
#
# Warning divide by zero on :
# hsa-mir-4718
# Negative: 0.0
# Posistive: 0.0010759816809692074
#
# Warning divide by zero on :
# hsa-mir-4719
# Negative: 0.0
# Posistive: 0.007795683520519717
#
# Warning divide by zero on :
# hsa-mir-4735
# Negative: 0.0
# Posistive: 0.04358211888173351
#
# Warning divide by zero on :
# hsa-mir-4737
# Negative: 0.0
# Posistive: 0.0025584276610756736
#
# Warning divide by zero on :
# hsa-mir-4739
# Negative: 0.0
# Posistive: 0.043790447678395635
#
# Warning divide by zero on :
# hsa-mir-4759
# Negative: 0.0
# Posistive: 0.002205849306250287
#
# Warning divide by zero on :
# hsa-mir-4764
# Negative: 0.0
# Posistive: 0.01622081210968645
#
# Warning divide by zero on :
# hsa-mir-4765
# Negative: 0.0
# Posistive: 0.003928096833325685
#
# Warning divide by zero on :
# hsa-mir-4774
# Negative: 0.0
# Posistive: 0.015869592443495464
#
# Warning divide by zero on :
# hsa-mir-4776-1
# Negative: 0.0
# Posistive: 0.02262732462629955
#
# Warning divide by zero on :
# hsa-mir-4776-2
# Negative: 0.0
# Posistive: 0.025128951444736727
#
# Warning divide by zero on :
# hsa-mir-4779
# Negative: 0.0
# Posistive: 0.018448705504880675
#
# Warning divide by zero on :
# hsa-mir-4780
# Negative: 0.0
# Posistive: 0.00887228788008811
#
# Warning divide by zero on :
# hsa-mir-4783
# Negative: 0.0
# Posistive: 0.005941743385139026
#
# Warning divide by zero on :
# hsa-mir-4790
# Negative: 0.0
# Posistive: 0.0031162885095911154
#
# Warning divide by zero on :
# hsa-mir-4801
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-4803
# Negative: 0.0
# Posistive: 0.010818208122848883
#
# Warning divide by zero on :
# hsa-mir-499b
# Negative: 0.0
# Posistive: 0.026773443784808316
#
# Warning divide by zero on :
# hsa-mir-5007
# Negative: 0.0
# Posistive: 0.0016179857652241752
#
# Warning divide by zero on :
# hsa-mir-5011
# Negative: 0.0
# Posistive: 0.00025246996466431095
#
# Warning divide by zero on :
# hsa-mir-5047
# Negative: 0.0
# Posistive: 0.008440458343382367
#
# Warning divide by zero on :
# hsa-mir-5093
# Negative: 0.0
# Posistive: 0.00855540966901843
#
# Warning divide by zero on :
# hsa-mir-5095
# Negative: 0.0
# Posistive: 0.0004861165934330687
#
# Warning divide by zero on :
# hsa-mir-5096
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-510
# Negative: 0.0
# Posistive: 0.03510807033063739
#
# Warning divide by zero on :
# hsa-mir-515-2
# Negative: 0.0
# Posistive: 0.36899682274530327
#
# Warning divide by zero on :
# hsa-mir-5186
# Negative: 0.0
# Posistive: 0.00012664853896103898
#
# Warning divide by zero on :
# hsa-mir-518d
# Negative: 0.0
# Posistive: 0.06270381830388692
#
# Warning divide by zero on :
# hsa-mir-518f
# Negative: 0.0
# Posistive: 4.570173388734393
#
# Warning divide by zero on :
# hsa-mir-5190
# Negative: 0.0
# Posistive: 0.0035345732419162397
#
# Warning divide by zero on :
# hsa-mir-5191
# Negative: 0.0
# Posistive: 0.005703098691776421
#
# Warning divide by zero on :
# hsa-mir-5192
# Negative: 0.0
# Posistive: 0.0034971319319310576
#
# Warning divide by zero on :
# hsa-mir-5194
# Negative: 0.0
# Posistive: 0.009337437835988815
#
# Warning divide by zero on :
# hsa-mir-5195
# Negative: 0.0
# Posistive: 0.007816549682234157
#
# Warning divide by zero on :
# hsa-mir-5196
# Negative: 0.0
# Posistive: 0.014278020052774081
#
# Warning divide by zero on :
# hsa-mir-5197
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-519d
# Negative: 0.0
# Posistive: 0.47633557889985284
#
# Warning divide by zero on :
# hsa-mir-519e
# Negative: 0.0
# Posistive: 0.07433242521502663
#
# Warning divide by zero on :
# hsa-mir-520d
# Negative: 0.0
# Posistive: 0.9193970313967406
#
# Warning divide by zero on :
# hsa-mir-520e
# Negative: 0.0
# Posistive: 1.0020287034345898
#
# Warning divide by zero on :
# hsa-mir-520h
# Negative: 0.0
# Posistive: 0.5773383449815847
#
# Warning divide by zero on :
# hsa-mir-521-2
# Negative: 0.0
# Posistive: 0.2939575889197375
#
# Warning divide by zero on :
# hsa-mir-523
# Negative: 0.0
# Posistive: 0.49454683273071454
#
# Warning divide by zero on :
# hsa-mir-524
# Negative: 0.0
# Posistive: 0.3664893878263962
#
# Warning divide by zero on :
# hsa-mir-526a-2
# Negative: 0.0
# Posistive: 0.08792068226263136
#
# Warning divide by zero on :
# hsa-mir-548a-1
# Negative: 0.0
# Posistive: 0.00011848674911660777
#
# Warning divide by zero on :
# hsa-mir-548a-2
# Negative: 0.0
# Posistive: 0.0012029045571566243
#
# Warning divide by zero on :
# hsa-mir-548aa-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548aa-2
# Negative: 0.0
# Posistive: 0.0003747516750034418
#
# Warning divide by zero on :
# hsa-mir-548ac
# Negative: 0.0
# Posistive: 0.00018554770318021202
#
# Warning divide by zero on :
# hsa-mir-548ad
# Negative: 0.0
# Posistive: 0.0019823794254508744
#
# Warning divide by zero on :
# hsa-mir-548ae-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548ae-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548aj-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548aj-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548ak
# Negative: 0.0
# Posistive: 0.007210366699336512
#
# Warning divide by zero on :
# hsa-mir-548am
# Negative: 0.0
# Posistive: 0.0009939912829838007
#
# Warning divide by zero on :
# hsa-mir-548an
# Negative: 0.0
# Posistive: 0.0011409229661328072
#
# Warning divide by zero on :
# hsa-mir-548ao
# Negative: 0.0
# Posistive: 0.014820662649710372
#
# Warning divide by zero on :
# hsa-mir-548ap
# Negative: 0.0
# Posistive: 0.0008895771580010095
#
# Warning divide by zero on :
# hsa-mir-548as
# Negative: 0.0
# Posistive: 0.0004599463626038273
#
# Warning divide by zero on :
# hsa-mir-548ax
# Negative: 0.0
# Posistive: 0.0031378605826946904
#
# Warning divide by zero on :
# hsa-mir-548bb
# Negative: 0.0
# Posistive: 0.0004149732448029003
#
# Warning divide by zero on :
# hsa-mir-548c
# Negative: 0.0
# Posistive: 0.00043705
#
# Warning divide by zero on :
# hsa-mir-548f-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548f-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548f-4
# Negative: 0.0
# Posistive: 0.012554492431393696
#
# Warning divide by zero on :
# hsa-mir-548f-5
# Negative: 0.0
# Posistive: 0.00014338392857142856
#
# Warning divide by zero on :
# hsa-mir-548g
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548h-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548h-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548h-3
# Negative: 0.0
# Posistive: 0.0004577736095176908
#
# Warning divide by zero on :
# hsa-mir-548h-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548h-5
# Negative: 0.0
# Posistive: 0.00023269886363636366
#
# Warning divide by zero on :
# hsa-mir-548i-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548i-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548i-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548i-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-548m
# Negative: 0.0
# Posistive: 0.0004980956108026249
#
# Warning divide by zero on :
# hsa-mir-548p
# Negative: 0.0
# Posistive: 0.0002300466563030609
#
# Warning divide by zero on :
# hsa-mir-548u
# Negative: 0.0
# Posistive: 0.003827629708480566
#
# Warning divide by zero on :
# hsa-mir-548w
# Negative: 0.0
# Posistive: 0.0011514375042448717
#
# Warning divide by zero on :
# hsa-mir-548z
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-550b-1
# Negative: 0.0
# Posistive: 0.0102157529656739
#
# Warning divide by zero on :
# hsa-mir-550b-2
# Negative: 0.0
# Posistive: 0.0053610126824147585
#
# Warning divide by zero on :
# hsa-mir-553
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-554
# Negative: 0.0
# Posistive: 0.00018938118374558303
#
# Warning divide by zero on :
# hsa-mir-557
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5572
# Negative: 0.0
# Posistive: 0.003919938687187371
#
# Warning divide by zero on :
# hsa-mir-558
# Negative: 0.0
# Posistive: 0.00018800084323803405
#
# Warning divide by zero on :
# hsa-mir-5583-1
# Negative: 0.0
# Posistive: 0.005185490590840255
#
# Warning divide by zero on :
# hsa-mir-5583-2
# Negative: 0.0
# Posistive: 0.01021818608264954
#
# Warning divide by zero on :
# hsa-mir-5587
# Negative: 0.0
# Posistive: 0.00636758492726355
#
# Warning divide by zero on :
# hsa-mir-5589
# Negative: 0.0
# Posistive: 0.060665314473602586
#
# Warning divide by zero on :
# hsa-mir-5590
# Negative: 0.0
# Posistive: 0.004353815437536362
#
# Warning divide by zero on :
# hsa-mir-5591
# Negative: 0.0
# Posistive: 0.0009161223140287275
#
# Warning divide by zero on :
# hsa-mir-562
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-563
# Negative: 0.0
# Posistive: 0.0009731824025974026
#
# Warning divide by zero on :
# hsa-mir-566
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-567
# Negative: 0.0
# Posistive: 0.0019575409728787114
#
# Warning divide by zero on :
# hsa-mir-568
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5688
# Negative: 0.0
# Posistive: 0.00035487234982332157
#
# Warning divide by zero on :
# hsa-mir-5689
# Negative: 0.0
# Posistive: 0.00023882557018952777
#
# Warning divide by zero on :
# hsa-mir-569
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5692a-1
# Negative: 0.0
# Posistive: 0.00043587632508833925
#
# Warning divide by zero on :
# hsa-mir-5692a-2
# Negative: 0.0
# Posistive: 0.00016004726148409893
#
# Warning divide by zero on :
# hsa-mir-5692b
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5692c-1
# Negative: 0.0
# Posistive: 0.002498000514088385
#
# Warning divide by zero on :
# hsa-mir-5692c-2
# Negative: 0.0
# Posistive: 0.002395511292620807
#
# Warning divide by zero on :
# hsa-mir-5700
# Negative: 0.0
# Posistive: 0.0002226800324675325
#
# Warning divide by zero on :
# hsa-mir-5701-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5701-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5701-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-5704
# Negative: 0.0
# Posistive: 0.0032624526843873097
#
# Warning divide by zero on :
# hsa-mir-5707
# Negative: 0.0
# Posistive: 0.0008862452721306961
#
# Warning divide by zero on :
# hsa-mir-5739
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-575
# Negative: 0.0
# Posistive: 0.005454890646952501
#
# Warning divide by zero on :
# hsa-mir-5787
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-583
# Negative: 0.0
# Posistive: 0.00045619549928869714
#
# Warning divide by zero on :
# hsa-mir-586
# Negative: 0.0
# Posistive: 0.002350245445711532
#
# Warning divide by zero on :
# hsa-mir-587
# Negative: 0.0
# Posistive: 0.0017706135953767538
#
# Warning divide by zero on :
# hsa-mir-591
# Negative: 0.0
# Posistive: 0.0039044932178274247
#
# Warning divide by zero on :
# hsa-mir-593
# Negative: 0.0
# Posistive: 0.0002778312987012987
#
# Warning divide by zero on :
# hsa-mir-595
# Negative: 0.0
# Posistive: 0.0001398321554770318
#
# Warning divide by zero on :
# hsa-mir-596
# Negative: 0.0
# Posistive: 0.0033573113551466204
#
# Warning divide by zero on :
# hsa-mir-601
# Negative: 0.0
# Posistive: 0.0003546528268551237
#
# Warning divide by zero on :
# hsa-mir-602
# Negative: 0.0
# Posistive: 0.005120658686010501
#
# Warning divide by zero on :
# hsa-mir-603
# Negative: 0.0
# Posistive: 0.012282985770645917
#
# Warning divide by zero on :
# hsa-mir-604
# Negative: 0.0
# Posistive: 0.0038032843022348674
#
# Warning divide by zero on :
# hsa-mir-606
# Negative: 0.0
# Posistive: 0.0027316798048506266
#
# Warning divide by zero on :
# hsa-mir-6068
# Negative: 0.0
# Posistive: 0.00032712396459547524
#
# Warning divide by zero on :
# hsa-mir-6069
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6070
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6071
# Negative: 0.0
# Posistive: 0.001929928587712299
#
# Warning divide by zero on :
# hsa-mir-6072
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6074
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6075
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6076
# Negative: 0.0
# Posistive: 0.005471210709352485
#
# Warning divide by zero on :
# hsa-mir-6077
# Negative: 0.0
# Posistive: 0.0034697371983846543
#
# Warning divide by zero on :
# hsa-mir-6078
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6079
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-608
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6080
# Negative: 0.0
# Posistive: 0.009338912426001562
#
# Warning divide by zero on :
# hsa-mir-6081
# Negative: 0.0
# Posistive: 0.00039538297634344457
#
# Warning divide by zero on :
# hsa-mir-6082
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6083
# Negative: 0.0
# Posistive: 0.0003848257142857143
#
# Warning divide by zero on :
# hsa-mir-6085
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6086
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6088
# Negative: 0.0
# Posistive: 0.0017094738829362816
#
# Warning divide by zero on :
# hsa-mir-6089-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6089-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6090
# Negative: 0.0
# Posistive: 0.00033117285714285715
#
# Warning divide by zero on :
# hsa-mir-610
# Negative: 0.0
# Posistive: 0.005006177772067781
#
# Warning divide by zero on :
# hsa-mir-6124
# Negative: 0.0
# Posistive: 0.00019927826855123675
#
# Warning divide by zero on :
# hsa-mir-6126
# Negative: 0.0
# Posistive: 0.0013390577775228307
#
# Warning divide by zero on :
# hsa-mir-6127
# Negative: 0.0
# Posistive: 0.00056078
#
# Warning divide by zero on :
# hsa-mir-6128
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6129
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-613
# Negative: 0.0
# Posistive: 0.0017191663743059064
#
# Warning divide by zero on :
# hsa-mir-6130
# Negative: 0.0
# Posistive: 0.0016705904589753686
#
# Warning divide by zero on :
# hsa-mir-6131
# Negative: 0.0
# Posistive: 0.0004379756493506494
#
# Warning divide by zero on :
# hsa-mir-6133
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6134
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6165
# Negative: 0.0
# Posistive: 0.0018773496617869763
#
# Warning divide by zero on :
# hsa-mir-617
# Negative: 0.0
# Posistive: 0.005631465695814786
#
# Warning divide by zero on :
# hsa-mir-619
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-620
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-621
# Negative: 0.0
# Posistive: 0.007778760960366147
#
# Warning divide by zero on :
# hsa-mir-622
# Negative: 0.0
# Posistive: 0.016667648348974346
#
# Warning divide by zero on :
# hsa-mir-623
# Negative: 0.0
# Posistive: 0.0015664654959616357
#
# Warning divide by zero on :
# hsa-mir-626
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-630
# Negative: 0.0
# Posistive: 0.0018621315967601304
#
# Warning divide by zero on :
# hsa-mir-633
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-634
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-635
# Negative: 0.0
# Posistive: 0.0018755277627231426
#
# Warning divide by zero on :
# hsa-mir-637
# Negative: 0.0
# Posistive: 0.001213041783190308
#
# Warning divide by zero on :
# hsa-mir-638
# Negative: 0.0
# Posistive: 0.006338855191822312
#
# Warning divide by zero on :
# hsa-mir-640
# Negative: 0.0
# Posistive: 0.0016986597276398515
#
# Warning divide by zero on :
# hsa-mir-644a
# Negative: 0.0
# Posistive: 0.0015174380893488138
#
# Warning divide by zero on :
# hsa-mir-645
# Negative: 0.0
# Posistive: 0.0006973940598182737
#
# Warning divide by zero on :
# hsa-mir-646
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-647
# Negative: 0.0
# Posistive: 0.0124351621907239
#
# Warning divide by zero on :
# hsa-mir-648
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-649
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-650
# Negative: 0.0
# Posistive: 0.0070607010294387595
#
# Warning divide by zero on :
# hsa-mir-6500
# Negative: 0.0
# Posistive: 0.008597570071100676
#
# Warning divide by zero on :
# hsa-mir-6511a-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6511a-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6511a-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6511a-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-657
# Negative: 0.0
# Posistive: 0.003082137811367078
#
# Warning divide by zero on :
# hsa-mir-661
# Negative: 0.0
# Posistive: 0.000981806752214217
#
# Warning divide by zero on :
# hsa-mir-663a
# Negative: 0.0
# Posistive: 0.0007438894038823367
#
# Warning divide by zero on :
# hsa-mir-6719
# Negative: 0.0
# Posistive: 0.0007717005844155843
#
# Warning divide by zero on :
# hsa-mir-6722
# Negative: 0.0
# Posistive: 0.001091912029507595
#
# Warning divide by zero on :
# hsa-mir-6724-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6724-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6724-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6724-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6745
# Negative: 0.0
# Posistive: 0.0024510729607406722
#
# Warning divide by zero on :
# hsa-mir-6752
# Negative: 0.0
# Posistive: 0.006554476641599595
#
# Warning divide by zero on :
# hsa-mir-6759
# Negative: 0.0
# Posistive: 0.005699523512111393
#
# Warning divide by zero on :
# hsa-mir-6760
# Negative: 0.0
# Posistive: 0.0001491576855123675
#
# Warning divide by zero on :
# hsa-mir-6770-1
# Negative: 0.0
# Posistive: 0.0027443603418842643
#
# Warning divide by zero on :
# hsa-mir-6770-2
# Negative: 0.0
# Posistive: 0.004217128671928779
#
# Warning divide by zero on :
# hsa-mir-6770-3
# Negative: 0.0
# Posistive: 0.005066998313757086
#
# Warning divide by zero on :
# hsa-mir-6780a
# Negative: 0.0
# Posistive: 0.010617667311097655
#
# Warning divide by zero on :
# hsa-mir-6785
# Negative: 0.0
# Posistive: 0.027666587885491346
#
# Warning divide by zero on :
# hsa-mir-6790
# Negative: 0.0
# Posistive: 0.007975278588578296
#
# Warning divide by zero on :
# hsa-mir-6791
# Negative: 0.0
# Posistive: 0.02307011186718104
#
# Warning divide by zero on :
# hsa-mir-6811
# Negative: 0.0
# Posistive: 0.03902758732601948
#
# Warning divide by zero on :
# hsa-mir-6828
# Negative: 0.0
# Posistive: 0.001589640531067872
#
# Warning divide by zero on :
# hsa-mir-6831
# Negative: 0.0
# Posistive: 0.010286656741973972
#
# Warning divide by zero on :
# hsa-mir-6835
# Negative: 0.0
# Posistive: 0.011032326407354472
#
# Warning divide by zero on :
# hsa-mir-6841
# Negative: 0.0
# Posistive: 0.006082804251644286
#
# Warning divide by zero on :
# hsa-mir-6859-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6859-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6859-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-6859-4
# Negative: 0.0
# Posistive: 0.000347762987012987
#
# Warning divide by zero on :
# hsa-mir-6862-1
# Negative: 0.0
# Posistive: 0.022323673328064564
#
# Warning divide by zero on :
# hsa-mir-6862-2
# Negative: 0.0
# Posistive: 0.016462391894474782
#
# Warning divide by zero on :
# hsa-mir-6863
# Negative: 0.0
# Posistive: 0.0017908488994309575
#
# Warning divide by zero on :
# hsa-mir-6864
# Negative: 0.0
# Posistive: 0.007687443452094753
#
# Warning divide by zero on :
# hsa-mir-6867
# Negative: 0.0
# Posistive: 0.020207898901836507
#
# Warning divide by zero on :
# hsa-mir-6876
# Negative: 0.0
# Posistive: 0.008568425114278461
#
# Warning divide by zero on :
# hsa-mir-7107
# Negative: 0.0
# Posistive: 0.004208084172623797
#
# Warning divide by zero on :
# hsa-mir-711
# Negative: 0.0
# Posistive: 0.0008516497349823323
#
# Warning divide by zero on :
# hsa-mir-7150
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-7151
# Negative: 0.0
# Posistive: 0.02331171084667612
#
# Warning divide by zero on :
# hsa-mir-7153
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-7154
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-7157
# Negative: 0.0
# Posistive: 0.008397894468473222
#
# Warning divide by zero on :
# hsa-mir-7158
# Negative: 0.0
# Posistive: 0.009317318523702446
#
# Warning divide by zero on :
# hsa-mir-7159
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-7162
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-718
# Negative: 0.0
# Posistive: 0.005438484149619331
#
# Warning divide by zero on :
# hsa-mir-7515
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-759
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-761
# Negative: 0.0
# Posistive: 0.000275892667844523
#
# Warning divide by zero on :
# hsa-mir-762
# Negative: 0.0
# Posistive: 0.00044944146390711766
#
# Warning divide by zero on :
# hsa-mir-764
# Negative: 0.0
# Posistive: 0.0008372460247349823
#
# Warning divide by zero on :
# hsa-mir-7704
# Negative: 0.0
# Posistive: 0.007515114010256528
#
# Warning divide by zero on :
# hsa-mir-7847
# Negative: 0.0
# Posistive: 0.002552564311842267
#
# Warning divide by zero on :
# hsa-mir-7852
# Negative: 0.0
# Posistive: 0.004440796339414318
#
# Warning divide by zero on :
# hsa-mir-7853
# Negative: 0.0
# Posistive: 0.0017981069268275893
#
# Warning divide by zero on :
# hsa-mir-7856
# Negative: 0.0
# Posistive: 0.002102448806158506
#
# Warning divide by zero on :
# hsa-mir-7973-1
# Negative: 0.0
# Posistive: 0.005995486349639759
#
# Warning divide by zero on :
# hsa-mir-7973-2
# Negative: 0.0
# Posistive: 0.0033207540871231242
#
# Warning divide by zero on :
# hsa-mir-7975
# Negative: 0.0
# Posistive: 0.00011627826855123675
#
# Warning divide by zero on :
# hsa-mir-7977
# Negative: 0.0
# Posistive: 0.0059473869245330645
#
# Warning divide by zero on :
# hsa-mir-7978
# Negative: 0.0
# Posistive: 0.01538143263594692
#
# Warning divide by zero on :
# hsa-mir-802
# Negative: 0.0
# Posistive: 0.010828896522876417
#
# Warning divide by zero on :
# hsa-mir-8052
# Negative: 0.0
# Posistive: 0.00045101136042402826
#
# Warning divide by zero on :
# hsa-mir-8053
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8054
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8055
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8056
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8057
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8058
# Negative: 0.0
# Posistive: 5.769787985865724e-05
#
# Warning divide by zero on :
# hsa-mir-8059
# Negative: 0.0
# Posistive: 0.0015355797433573494
#
# Warning divide by zero on :
# hsa-mir-8060
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8061
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8062
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8063
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8064
# Negative: 0.0
# Posistive: 0.000909430731150475
#
# Warning divide by zero on :
# hsa-mir-8065
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8066
# Negative: 0.0
# Posistive: 0.0029739018506493506
#
# Warning divide by zero on :
# hsa-mir-8067
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8068
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8069-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8069-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8070
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8071-1
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8071-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8073
# Negative: 0.0
# Posistive: 0.0018714094167316781
#
# Warning divide by zero on :
# hsa-mir-8074
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8075
# Negative: 0.0
# Posistive: 0.00039310781974209535
#
# Warning divide by zero on :
# hsa-mir-8076
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8077
# Negative: 0.0
# Posistive: 0.007677943251460725
#
# Warning divide by zero on :
# hsa-mir-8078
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8079
# Negative: 0.0
# Posistive: 0.005808752513515494
#
# Warning divide by zero on :
# hsa-mir-8080
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8081
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8082
# Negative: 0.0
# Posistive: 0.0013311209677419355
#
# Warning divide by zero on :
# hsa-mir-8083
# Negative: 0.0
# Posistive: 0.002106248386608262
#
# Warning divide by zero on :
# hsa-mir-8084
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8086
# Negative: 0.0
# Posistive: 8.884143109540636e-05
#
# Warning divide by zero on :
# hsa-mir-8087
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8088
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-8089
# Negative: 0.0
# Posistive: 9.325795053003533e-05
#
# Warning divide by zero on :
# hsa-mir-8485
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-890
# Negative: 0.0
# Posistive: 0.03260212582374567
#
# Warning divide by zero on :
# hsa-mir-920
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-921
# Negative: 0.0
# Posistive: 0.0004077814285714286
#
# Warning divide by zero on :
# hsa-mir-922
# Negative: 0.0
# Posistive: 0.008399025923087514
#
# Warning divide by zero on :
# hsa-mir-924
# Negative: 0.0
# Posistive: 0.000217238074204947
#
# Warning divide by zero on :
# hsa-mir-933
# Negative: 0.0
# Posistive: 0.01736934335382986
#
# Warning divide by zero on :
# hsa-mir-941-1
# Negative: 0.0
# Posistive: 0.01137638651991944
#
# Warning divide by zero on :
# hsa-mir-941-2
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-941-3
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-941-4
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-941-5
# Negative: 0.0
# Posistive: 0.0
#
# Warning divide by zero on :
# hsa-mir-9500
# Negative: 0.0
# Posistive: 0.0

# %%
rpm_log_fold_change = pd.DataFrame.from_dict(rpm_log_fold_change, orient='index')

rpm_log_fold_change.head(5)
# Out:
#                      0
# hsa-let-7a-1  0.073503
# hsa-let-7a-2  0.078287
# hsa-let-7a-3  0.072661
# hsa-let-7b    0.174374
# hsa-let-7c   -0.352575

# %%
rpm_log_fold_change_sorted = rpm_log_fold_change.sort_values(by = 0, ascending=False)

print("Top 10 most upregualted genes in lung cancer paitents")
rpm_log_fold_change_sorted.head(10)
# Out:
# Top 10 most upregualted genes in lung cancer paitents
#                        0
# hsa-mir-520a    8.776809
# hsa-mir-520f    7.479981
# hsa-mir-518c    7.341205
# hsa-mir-516b-1  6.974440
# hsa-mir-512-1   6.891411
# hsa-mir-525     6.885598
# hsa-mir-518a-2  6.594470
# hsa-mir-518b    6.498128
# hsa-mir-520c    6.482026
# hsa-mir-526b    6.481238

# %%
print("Top 10 most downregulated genes in lung cancer paitents")
rpm_log_fold_change_sorted.tail(10)
# Out:
# Top 10 most downregulated genes in lung cancer paitents
#                      0
# hsa-mir-4439 -2.762795
# hsa-mir-4510 -2.777789
# hsa-mir-663b -2.855177
# hsa-mir-3937 -2.910867
# hsa-mir-8085 -2.992225
# hsa-mir-1282 -3.625630
# hsa-mir-3907 -3.888020
# hsa-mir-631  -4.137240
# hsa-mir-4663 -6.025543
# hsa-mir-571  -6.052735
