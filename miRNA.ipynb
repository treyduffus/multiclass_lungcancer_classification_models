# %% [markdown]
# ### Import Libraries

# %%
import json
import os
import pandas as pd
import numpy as np
from pprint import pprint

# %% [markdown]
# ### Load Metadata and Clinical JSON Files

# %%
# Load JSON data for metadata and clinical information
# Ensure these files are located in the same directory or provide the full path if they are located elsewhere
with open('metadata.cart.2024-10-27.json') as metadata_file:
    metadata = json.load(metadata_file)

with open('clinical.cart.2024-10-27.json') as clinical_file:
    clinical = json.load(clinical_file)

# Display a sample entry from metadata and clinical to verify the structure
pprint(metadata[0])  # Display the first entry of metadata
pprint(clinical[0])  # Display the first entry of clinical data
# Out:
# {'access': 'open',
#  'analysis': {'analysis_id': '760850fa-8b86-49fb-be5f-8f8f5c6dbea4',
#               'created_datetime': '2018-03-20T15:27:35.798083-05:00',
#               'input_files': [{'access': 'controlled',
#                                'created_datetime': '2018-03-20T15:27:35.798083-05:00',
#                                'data_category': 'Sequencing Reads',
#                                'data_format': 'BAM',
#                                'data_type': 'Aligned Reads',
#                                'experimental_strategy': 'miRNA-Seq',
#                                'file_id': 'cc5deb2c-cad3-4bad-869c-5e37f5a4ca6b',
#                                'file_name': 'TCGA-21-A5DI-01A-31H-A26V-13_mirna_gdc_realn.bam',
#                                'file_size': 157942346,
#                                'md5sum': '9f120e02415d1c617d8c23f68e0424fd',
#                                'platform': 'Illumina',
#                                'state': 'released',
#                                'submitter_id': 'mirna_swap_dr11_51_AlignedReadsab802531-92a2-438a-9271-58d6a52dd17f',
#                                'updated_datetime': '2023-07-12T10:30:47.064137-05:00',
#                                'wgs_coverage': 'Not Applicable'}],
#               'state': 'released',
#               'submitter_id': 'mirna_swap_dr11_51_MirnaExpressionWorkflowc1ca30b1-e65b-46dc-93c7-bcb19de553a7_pipeline:mirnaseq0.0.1',
#               'updated_datetime': '2018-09-06T16:31:22.449726-05:00',
#               'workflow_link': 'https://github.com/NCI-GDC/gdc-dnaseq-cwl/blob/gdc-active-submission/workflows/mirnaseq/runner.cwl',
#               'workflow_type': 'BCGSC miRNA Profiling'},
#  'annotations': [{'annotation_id': '138ee9d9-fe15-5530-ac8a-aa9d51b43d57',
#                   'case_id': 'a7cd7b0f-ab76-4f3f-a2d5-5ec04fe6c4f3',
#                   'case_submitter_id': 'TCGA-21-A5DI',
#                   'category': 'History of unacceptable prior treatment related '
#                               'to a prior/other malignancy',
#                   'classification': 'Notification',
#                   'created_datetime': '2014-06-16T00:00:00',
#                   'entity_id': 'a7cd7b0f-ab76-4f3f-a2d5-5ec04fe6c4f3',
#                   'entity_submitter_id': 'TCGA-21-A5DI',
#                   'entity_type': 'case',
#                   'notes': 'unknown treatment history',
#                   'state': 'released',
#                   'status': 'Approved',
#                   'submitter_id': '20737',
#                   'updated_datetime': '2018-08-23T16:28:11.210272-05:00'}],
#  'associated_entities': [{'case_id': 'a7cd7b0f-ab76-4f3f-a2d5-5ec04fe6c4f3',
#                           'entity_id': '7d734ccb-f545-4332-9288-3f86f8adbb2c',
#                           'entity_submitter_id': 'TCGA-21-A5DI-01A-31H-A26V-13',
#                           'entity_type': 'aliquot'}],
#  'data_category': 'Transcriptome Profiling',
#  'data_format': 'TXT',
#  'data_type': 'miRNA Expression Quantification',
#  'experimental_strategy': 'miRNA-Seq',
#  'file_id': '4a8f4158-92ab-42a6-ac2f-d688bdd6b39b',
#  'file_name': '2eb7b98e-ef32-4458-98e2-fe5c129f2dad.mirbase21.mirnas.quantification.txt',
#  'file_size': 50324,
#  'md5sum': 'e189f1c3d6958d61ab606bbda9f15d30',
#  'platform': 'Illumina',
#  'state': 'released',
#  'submitter_id': 'mirna_swap_dr11_51_MirnaExpressionab802531-92a2-438a-9271-58d6a52dd17f_profiling'}
# {'case_id': '005669e5-1a31-45fb-ae97-9d450e74e7cb',
#  'demographic': {'age_at_index': 70,
#                  'days_to_birth': -25654,
#                  'days_to_death': 840,
#                  'demographic_id': '6ed6aede-1183-5b9c-ae3c-8a7d7d30e127',
#                  'ethnicity': 'not reported',
#                  'gender': 'male',
#                  'race': 'not reported',
#                  'state': 'released',
#                  'submitter_id': 'TCGA-77-A5GF_demographic',
#                  'updated_datetime': '2019-07-31T19:13:14.772512-05:00',
#                  'vital_status': 'Dead',
#                  'year_of_birth': 1941},
#  'diagnoses': [{'age_at_diagnosis': 25654,
#                 'ajcc_pathologic_m': 'M0',
#                 'ajcc_pathologic_n': 'N1',
#                 'ajcc_pathologic_stage': 'Stage IIA',
#                 'ajcc_pathologic_t': 'T2a',
#                 'ajcc_staging_system_edition': '7th',
#                 'classification_of_tumor': 'not reported',
#                 'days_to_diagnosis': 0,
#                 'days_to_last_follow_up': 839.0,
#                 'diagnosis_id': '0d7b0c18-913f-5cf8-89aa-f7f758ab7fda',
#                 'icd_10_code': 'C34.3',
#                 'last_known_disease_status': 'not reported',
#                 'morphology': '8070/3',
#                 'primary_diagnosis': 'Squamous cell carcinoma, NOS',
#                 'prior_malignancy': 'no',
#                 'prior_treatment': 'No',
#                 'progression_or_recurrence': 'not reported',
#                 'site_of_resection_or_biopsy': 'Lower lobe, lung',
#                 'state': 'released',
#                 'submitter_id': 'TCGA-77-A5GF_diagnosis',
#                 'synchronous_malignancy': 'No',
#                 'tissue_or_organ_of_origin': 'Lower lobe, lung',
#                 'treatments': [{'created_datetime': '2019-04-28T11:51:10.435902-05:00',
#                                 'state': 'released',
#                                 'submitter_id': 'TCGA-77-A5GF_treatment_1',
#                                 'treatment_id': '551c8e5e-a9fa-5535-ad36-feebeb563530',
#                                 'treatment_or_therapy': 'no',
#                                 'treatment_type': 'Pharmaceutical Therapy, NOS',
#                                 'updated_datetime': '2019-07-31T19:13:14.772512-05:00'},
#                                {'state': 'released',
#                                 'submitter_id': 'TCGA-77-A5GF_treatment',
#                                 'treatment_id': '86086bdd-1f53-5d80-9748-ea6a4ddfabd3',
#                                 'treatment_or_therapy': 'no',
#                                 'treatment_type': 'Radiation Therapy, NOS',
#                                 'updated_datetime': '2019-07-31T19:13:14.772512-05:00'}],
#                 'tumor_grade': 'Not Reported',
#                 'updated_datetime': '2023-10-06T12:22:59.118523-05:00',
#                 'year_of_diagnosis': 2011}],
#  'exposures': [{'alcohol_history': 'Not Reported',
#                 'cigarettes_per_day': 3.287671232876712,
#                 'exposure_id': '45c78284-297d-5289-aa01-8c89f428d913',
#                 'pack_years_smoked': 60.0,
#                 'state': 'released',
#                 'submitter_id': 'TCGA-77-A5GF_exposure',
#                 'updated_datetime': '2019-07-31T19:13:14.772512-05:00',
#                 'years_smoked': 40.0}],
#  'project': {'project_id': 'TCGA-LUSC'},
#  'submitter_id': 'TCGA-77-A5GF'}

# %% [markdown]
# ### Extract file_id and case_id from Metadata

# %%
# Initialize an empty list to store file_id and case_id pairs
labels = []

# Extract 'file_id' and 'case_id' from each entry in metadata
for entry in metadata:
    file_id = entry['file_id']
    case_id = entry['associated_entities'][0]['case_id']  # Assumes 'associated_entities' is a list with one element
    labels.append({'file_id': file_id, 'case_id': case_id})

# Display the extracted labels to verify correctness
pprint(labels[:5])  # Display the first 5 entries of labels
# Out:
# [{'case_id': 'a7cd7b0f-ab76-4f3f-a2d5-5ec04fe6c4f3',
#   'file_id': '4a8f4158-92ab-42a6-ac2f-d688bdd6b39b'},
#  {'case_id': 'dbece124-c042-4adc-8136-90e7940ee6ad',
#   'file_id': 'b688460b-5c4a-4eaa-84fc-302f29c47def'},
#  {'case_id': 'dbece124-c042-4adc-8136-90e7940ee6ad',
#   'file_id': '3de2e5b4-fdde-4b37-91e7-21a72ccc97f9'},
#  {'case_id': '7b982d5e-3a7d-40ac-bd25-6044c62879b6',
#   'file_id': 'fd4e10cd-b09d-4797-abb0-c039248c9def'},
#  {'case_id': '3351b902-9b7e-4b90-bf6b-bcf74be00bc1',
#   'file_id': 'a7d5bf83-d019-4379-93b2-d15be80fe95d'}]

# %% [markdown]
# ### Match case_id with Clinical Data to Retrieve ajcc_pathologic_stag

# %%
# Counter for matched entries (similar to 'm' in MATLAB)
match_count = 0

# Loop through each clinical entry and find corresponding case_id in labels
for clinical_entry in clinical:
    # Check if 'diagnoses' and 'ajcc_pathologic_stage' fields are present
    if 'diagnoses' in clinical_entry and 'ajcc_pathologic_stage' in clinical_entry['diagnoses']:
        case_id = clinical_entry['case_id']
        
        # Search for matching case_id in labels
        for label in labels:
            if label['case_id'] == case_id:
                # If case_id matches, add the 'ajcc_pathologic_stage' as 'label'
                label['label'] = clinical_entry['diagnoses']['ajcc_pathologic_stage']
                match_count += 1

# Display the updated labels list with added 'label' fields to verify
pprint(labels[:5])  # Display the first 5 entries to verify stages have been added
print("Total matches found:", match_count)
# Out:
# [{'case_id': 'a7cd7b0f-ab76-4f3f-a2d5-5ec04fe6c4f3',
#   'file_id': '4a8f4158-92ab-42a6-ac2f-d688bdd6b39b'},
#  {'case_id': 'dbece124-c042-4adc-8136-90e7940ee6ad',
#   'file_id': 'b688460b-5c4a-4eaa-84fc-302f29c47def'},
#  {'case_id': 'dbece124-c042-4adc-8136-90e7940ee6ad',
#   'file_id': '3de2e5b4-fdde-4b37-91e7-21a72ccc97f9'},
#  {'case_id': '7b982d5e-3a7d-40ac-bd25-6044c62879b6',
#   'file_id': 'fd4e10cd-b09d-4797-abb0-c039248c9def'},
#  {'case_id': '3351b902-9b7e-4b90-bf6b-bcf74be00bc1',
#   'file_id': 'a7d5bf83-d019-4379-93b2-d15be80fe95d'}]
# Total matches found: 0

# %% [markdown]
# ### Map ajcc_pathologic_stage to Numerical Labels

# %%
# Initialize an empty list for the numerical labels
numerical_labels = []

# Check the unique values of the label field in labels to understand its contents
unique_stages = set(entry.get('label', 'No label') for entry in labels)
print("Unique stages found in labels:", unique_stages)

# Map each clinical stage to a number and add to the numerical_labels list
for entry in labels:
    # Retrieve the stage label, strip whitespace, and convert to uppercase for uniformity
    stage = entry.get('label', '').strip().upper()
    print(f"Mapping stage: {stage}")  # Diagnostic output for each stage

    # Map stage to numerical labels
    if stage in ['STAGE I', 'STAGE IA', 'STAGE IB']:
        numerical_labels.append(1)  # Cancer Stage I
        print("Mapped to: 1")
    elif stage in ['STAGE II', 'STAGE IIA', 'STAGE IIB']:
        numerical_labels.append(2)  # Cancer Stage II
        print("Mapped to: 2")
    elif stage in ['STAGE III', 'STAGE IIIA', 'STAGE IIIB']:
        numerical_labels.append(3)  # Cancer Stage III
        print("Mapped to: 3")
    elif stage in ['STAGE IV', 'STAGE IVA', 'STAGE IVB']:
        numerical_labels.append(4)  # Cancer Stage IV
        print("Mapped to: 4")
    else:
        numerical_labels.append(0)  # Healthy patient (non-cancerous)
        print("Mapped to: 0 (healthy patient)")

# Display the first 10 entries in numerical_labels to verify the mapping
print("First 10 entries in numerical_labels:", numerical_labels[:10])
# Out:
# Unique stages found in labels: {'', 'Stage IIB', 'Stage III', 'Stage IV', 'Stage IIIA', 'Stage II', 'Stage I', 'Stage IA', 'Stage IIA', 'Stage IB', 'Stage IIIB', 'No label'}
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE II
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE III
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE II
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE III
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE III
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE II
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IV
# Mapped to: 4
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE I
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE II
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE III
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIA
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage:
# Mapped to: 0 (healthy patient)
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IIIA
# Mapped to: 3
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IIIB
# Mapped to: 3
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IA
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIB
# Mapped to: 2
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IB
# Mapped to: 1
# Mapping stage: STAGE IIA
# Mapped to: 2
# First 10 entries in numerical_labels: [1, 1, 0, 1, 1, 1, 1, 3, 1, 1]

# %% [markdown]
# ### Read miRNA Quantification Files

# %%
# Define the directory containing the training files
TrainDir = './Train'  # Update this path if necessary
data_list = []  # List to store the extracted data
file_ids = []   # List to store file IDs

# Traverse each folder within the Train directory
for folder_name in os.listdir(TrainDir):
    folder_path = os.path.join(TrainDir, folder_name)
    
    # Check if it's a directory
    if os.path.isdir(folder_path):
        # Find .mirnas.quantific files in the current directory
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.mirnas.quantific'):
                file_path = os.path.join(folder_path, file_name)
                
                # Read the file as a DataFrame
                df = pd.read_csv(file_path, sep='\t')
                
                # Check if the data has the expected 1881 rows
                if df.shape[0] == 1881:
                    # Extract the third column and convert it to a list, then append it
                    data_list.append(df.iloc[:, 2].values)  # Third column assumed to be index 2
                    file_ids.append(folder_name)  # Use the folder name as the file ID
                else:
                    print(f"Warning: File {file_path} does not have 1881 rows")

# %% [markdown]
#  ### Create the Feature Matrix and Append Labels

# %%
# Convert data_list directly into a DataFrame (no transpose needed)
data_matrix = pd.DataFrame(data_list)

# Add the numerical labels as the last column in data_matrix
data_matrix['Label'] = numerical_labels

# Display the data matrix to verify structure
data_matrix.head()
# Out:
#               0             1             2             3            4  \
# 0   7314.747386   7391.483138   7334.393081  10994.201497   471.496698
# 1   9518.042994   9460.443528   9574.874468  17578.281899   785.810318
# 2   4479.976340   4387.407628   4447.955716  12394.310110   404.624244
# 3  21277.962603  21166.590502  21255.800397  15161.474118  6684.570363
# 4   8002.355461   8013.396682   8033.638922  19358.942067  1276.411235
#
#             5            6             7             8            9  ...  \
# 0  318.193106  1156.241547   3272.099771   3363.611772   442.783758  ...
# 1  358.652676   771.986446   3871.452122   3917.224498   487.829079  ...
# 2  855.241747   246.267705   1353.016896   1415.311564   416.850300  ...
# 3  503.278464  2185.922959  15012.229891  14987.262342  1107.549261  ...
# 4  765.754731   593.005616   2630.801098   2649.433160   367.580673  ...
#
#        1872  1873        1874       1875  1876       1877       1878  \
# 0  3.022415   0.0    0.000000   1.847031   0.0  40.298863  35.429417
# 1  6.451140   0.0  128.562009   4.607957   0.0   8.601520  38.860440
# 2  2.910966   0.0  161.267504   1.746579   0.0  33.767203  31.438430
# 3  6.452288   0.0    1.683206  10.660302   0.0   5.049617  95.101114
# 4  9.201018   0.0   97.990843   3.450382   0.0  22.772520  46.235116
#
#           1879          1880  Label
# 0   148.602058  12118.707689      1
# 1   111.512567   7471.802757      1
# 2   168.253822  16026.613214      0
# 3  1416.978551  12750.562682      1
# 4   455.450396  14401.203493      1
#
# [5 rows x 1882 columns]

# %% [markdown]
# ### Add Column Names and Save to CSV

# %%
# Use the miRNA IDs from the first file as column names, with 'Label' as the final column name
miRNA_ids = list(pd.read_csv(os.path.join(TrainDir, os.listdir(TrainDir)[0], os.listdir(os.path.join(TrainDir, os.listdir(TrainDir)[0]))[0]), sep='\t').iloc[:, 0])
column_names = miRNA_ids + ['Label']

# Set the column names for the data matrix
data_matrix.columns = column_names

# Save the feature matrix to 'Lung.csv'
data_matrix.to_csv('Lung.csv', index=False)

print("Lung.csv created successfully.")
# Out:
# Lung.csv created successfully.
